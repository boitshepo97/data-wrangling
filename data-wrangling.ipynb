# %% [markdown]
# # Data Wrangling.

# %%
# loading modules
from IPython.display import display, HTML
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
personality = pd.read_csv('personality_scores.csv', sep=';')

# %%
#checking for duplicates in the data set.
duplicateRowsDF = personality[personality.duplicated(['ID'])]

# %%
#checking for duplicates in the data set.
personality.drop_duplicates(subset=['ID'], inplace=True)

# Assert Statement for modification.
personality['ID'].unique().sum() == personality['ID'].sum()
# Out:
# True

# %%
personality.head()
# Out:
#    ID Section 5 of 6 [I am always prepared.]  \
# 0   0                                 (3, 5)
# 1   1                                 (3, 5)
# 2   2                                 (3, 5)
# 3   3                                 (3, 5)
# 4   4                                 (3, 3)
#
#   Section 5 of 6 [I am easily disturbed.]  \
# 0                                  (4, 5)
# 1                                  (4, 5)
# 2                                  (4, 3)
# 3                                  (4, 5)
# 4                                  (4, 5)
#
#   Section 5 of 6 [I am exacting (demanding) in my work.]  \
# 0                                             (3, 5)
# 1                                             (3, 5)
# 2                                             (3, 3)
# 3                                             (3, 3)
# 4                                             (3, 3)
#
#   Section 5 of 6 [I am full of ideas.]  \
# 0                               (5, 5)
# ...

# %%
#creating new columns
pd.concat([personality, pd.DataFrame(columns = ['conscientiousness', 'emotional stability', 'openness to new experience', 'agreeableness', 'extraversion'])],sort=True)

personality
# Out:
#         ID Section 5 of 6 [I am always prepared.]  \
# 0        0                                 (3, 5)
# 1        1                                 (3, 5)
# 2        2                                 (3, 5)
# 3        3                                 (3, 5)
# 4        4                                 (3, 3)
# ...    ...                                    ...
# 1550  1550                                 (3, 5)
# 1551  1551                                 (3, 3)
# 1552  1552                                 (3, 5)
# 1553  1553                                 (3, 5)
# 1554  1554                                 (3, 3)
#
#      Section 5 of 6 [I am easily disturbed.]  \
# 0                                     (4, 5)
# 1                                     (4, 5)
# 2                                     (4, 3)
# 3                                     (4, 5)
# 4                                     (4, 5)
# ...                                      ...
# ...

# %%
income = []
for index, columns in mob_mon_incomes.iterrows():
    # this will give you a list of values in your row.
    row = list(row)

    # you want to remove all "none" values from your list.
    nfl = remove_none(row)

    # *if* your list is empty after the process of elimination, you want to append "No income".
    if len(nfl) == 0:
        nfl.append("No income")
    
    income.append(nfl)

mob_mon['income_type'] = income

# %%
departments = pd.read_csv('departments.csv', sep=';')
pers_by_dept = pd.merge(personality, departments).set_index('ID')

# %%
pers_by_dept
# Out:
#      Section 5 of 6 [I am always prepared.]  \
# ID
# 0                                    (3, 5)
# 1                                    (3, 5)
# 2                                    (3, 5)
# 3                                    (3, 5)
# 4                                    (3, 3)
# ...                                     ...
# 1550                                 (3, 5)
# 1551                                 (3, 3)
# 1552                                 (3, 5)
# 1553                                 (3, 5)
# 1554                                 (3, 3)
#
#      Section 5 of 6 [I am easily disturbed.]  \
# ID
# 0                                     (4, 5)
# 1                                     (4, 5)
# 2                                     (4, 3)
# 3                                     (4, 5)
# 4                                     (4, 5)
# ...                                      ...
# 1550                                  (4, 5)
# 1551                                  (4, 5)
# ...

# %%
# Assert Statement for modification.
len(pers_by_dept) == len(departments)
# Out:
# True
